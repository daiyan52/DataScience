# %%
import pandas as pd
import csv
nitian = pd.read_csv('/Users/daiyanalam/Documents/MachineLearnig/Dataset/NIT_2024.csv')
nitian
# Out:
#                     Name                       Email id   Phone no.  \
# 0           AAYUSH GUPTA        1aayushgupta1@gmail.com  9831019428
# 1            ABDUL KARIM             ak.kar8m@gmail.com  9883259930
# 2              ADIL KHAN      shallycarrera34@gmail.com  8240660823
# 3         ADITYA BHUSHAN    adityabhushan1517@gmail.com  8002151109
# 4              AKASH RAJ        akashraj32124@gmail.com  7542046123
# ..                   ...                            ...         ...
# 324           TANAYA PAL        tanayapalstar@gmail.com  7866937953
# 325  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6377689721
# 326          VIBHUTI RAJ          vibhu421420@gmail.com  7542013535
# 327         VINEET YADAV       yadavvineet872@gmail.com  6391605757
# 328         YUVRAJ SINGH          yuvraj28541@gmail.com  8709187575
#
#     Branch/ Stream  Overall CGPA College
# 0              CSE          7.71     NIT
# 1              CSE          9.06     NIT
# ...

# %%
type(nitian)
# Out:
# pandas.core.frame.DataFrame

# %%
df = nitian.copy()

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#              Name                     Email id   Phone no. Branch/ Stream  \
# 0    AAYUSH GUPTA      1aayushgupta1@gmail.com  9831019428            CSE
# 1     ABDUL KARIM           ak.kar8m@gmail.com  9883259930            CSE
# 2       ADIL KHAN    shallycarrera34@gmail.com  8240660823            CSE
# 3  ADITYA BHUSHAN  adityabhushan1517@gmail.com  8002151109            CSE
# 4       AKASH RAJ      akashraj32124@gmail.com  7542046123            CSE
#
#    Overall CGPA College
# 0          7.71     NIT
# 1          9.06     NIT
# 2          8.91     NIT
# 3          8.50     NIT
# 4          8.91     NIT

# %%
df.tail()
# Out:
#                     Name                       Email id   Phone no.  \
# 324           TANAYA PAL        tanayapalstar@gmail.com  7866937953
# 325  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6377689721
# 326          VIBHUTI RAJ          vibhu421420@gmail.com  7542013535
# 327         VINEET YADAV       yadavvineet872@gmail.com  6391605757
# 328         YUVRAJ SINGH          yuvraj28541@gmail.com  8709187575
#
#     Branch/ Stream  Overall CGPA College
# 324             IT          8.74     NIT
# 325             IT          8.73     NIT
# 326             IT          8.82     NIT
# 327             IT          8.56     NIT
# 328             IT          8.46     NIT

# %%
df.head(10)
# Out:
#                Name                     Email id   Phone no. Branch/ Stream  \
# 0      AAYUSH GUPTA      1aayushgupta1@gmail.com  9831019428            CSE
# 1       ABDUL KARIM           ak.kar8m@gmail.com  9883259930            CSE
# 2         ADIL KHAN    shallycarrera34@gmail.com  8240660823            CSE
# 3    ADITYA BHUSHAN  adityabhushan1517@gmail.com  8002151109            CSE
# 4         AKASH RAJ      akashraj32124@gmail.com  7542046123            CSE
# 5        AMAN KUMAR     amanaolsingh55@gmail.com  8340352235            CSE
# 6        AMAN KUMAR       aman.cute329@gmail.com  6287958624            CSE
# 7  AMAN KUMAR SINHA         amankr7100@gmail.com  8092678031            CSE
# 8  AMAR KUMAR SINGH   amar18kumarsingh@gmail.com  9051914838            CSE
# 9       AMIT SARKAR          amj153942@gmail.com  7001266603            CSE
#
#    Overall CGPA College
# 0          7.71     NIT
# 1          9.06     NIT
# 2          8.91     NIT
# 3          8.50     NIT
# ...

# %%
df.isnull()
# Out:
#       Name  Email id  Phone no.  Branch/ Stream  Overall CGPA  College
# 0    False     False      False           False         False    False
# 1    False     False      False           False         False    False
# 2    False     False      False           False         False    False
# 3    False     False      False           False         False    False
# 4    False     False      False           False         False    False
# ..     ...       ...        ...             ...           ...      ...
# 324  False     False      False           False         False    False
# 325  False     False      False           False         False    False
# 326  False     False      False           False         False    False
# 327  False     False      False           False         False    False
# 328  False     False      False           False         False    False
#
# [329 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Name              0
# Email id          0
# Phone no.         0
# Branch/ Stream    0
# Overall CGPA      0
# College           0
# dtype: int64

# %%
df.iloc[2:10]
# Out:
#                Name                     Email id   Phone no. Branch/ Stream  \
# 2         ADIL KHAN    shallycarrera34@gmail.com  8240660823            CSE
# 3    ADITYA BHUSHAN  adityabhushan1517@gmail.com  8002151109            CSE
# 4         AKASH RAJ      akashraj32124@gmail.com  7542046123            CSE
# 5        AMAN KUMAR     amanaolsingh55@gmail.com  8340352235            CSE
# 6        AMAN KUMAR       aman.cute329@gmail.com  6287958624            CSE
# 7  AMAN KUMAR SINHA         amankr7100@gmail.com  8092678031            CSE
# 8  AMAR KUMAR SINGH   amar18kumarsingh@gmail.com  9051914838            CSE
# 9       AMIT SARKAR          amj153942@gmail.com  7001266603            CSE
#
#    Overall CGPA College
# 2          8.91     NIT
# 3          8.50     NIT
# 4          8.91     NIT
# 5          8.55     NIT
# 6          8.66     NIT
# 7          8.92     NIT
# 8          8.37     NIT
# 9          9.38     NIT

# %%
df.columns
# Out:
# Index(['Name', 'Email id', 'Phone no.', 'Branch/ Stream', 'Overall CGPA',
#        'College'],
#       dtype='object')

# %%
df.columns = ['NAME','EMAIL','PHONE','STREAM','Avg. CGPA','COLLEGE']

# %%
df
# Out:
#                     NAME                          EMAIL       PHONE STREAM  \
# 0           AAYUSH GUPTA        1aayushgupta1@gmail.com  9831019428    CSE
# 1            ABDUL KARIM             ak.kar8m@gmail.com  9883259930    CSE
# 2              ADIL KHAN      shallycarrera34@gmail.com  8240660823    CSE
# 3         ADITYA BHUSHAN    adityabhushan1517@gmail.com  8002151109    CSE
# 4              AKASH RAJ        akashraj32124@gmail.com  7542046123    CSE
# ..                   ...                            ...         ...    ...
# 324           TANAYA PAL        tanayapalstar@gmail.com  7866937953     IT
# 325  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6377689721     IT
# 326          VIBHUTI RAJ          vibhu421420@gmail.com  7542013535     IT
# 327         VINEET YADAV       yadavvineet872@gmail.com  6391605757     IT
# 328         YUVRAJ SINGH          yuvraj28541@gmail.com  8709187575     IT
#
#      Avg. CGPA COLLEGE
# 0         7.71     NIT
# ...

# %%
df.head(10)
# Out:
#                NAME                        EMAIL       PHONE STREAM  \
# 0      AAYUSH GUPTA      1aayushgupta1@gmail.com  9831019428    CSE
# 1       ABDUL KARIM           ak.kar8m@gmail.com  9883259930    CSE
# 2         ADIL KHAN    shallycarrera34@gmail.com  8240660823    CSE
# 3    ADITYA BHUSHAN  adityabhushan1517@gmail.com  8002151109    CSE
# 4         AKASH RAJ      akashraj32124@gmail.com  7542046123    CSE
# 5        AMAN KUMAR     amanaolsingh55@gmail.com  8340352235    CSE
# 6        AMAN KUMAR       aman.cute329@gmail.com  6287958624    CSE
# 7  AMAN KUMAR SINHA         amankr7100@gmail.com  8092678031    CSE
# 8  AMAR KUMAR SINGH   amar18kumarsingh@gmail.com  9051914838    CSE
# 9       AMIT SARKAR          amj153942@gmail.com  7001266603    CSE
#
#    Avg. CGPA COLLEGE
# 0       7.71     NIT
# 1       9.06     NIT
# 2       8.91     NIT
# 3       8.50     NIT
# 4       8.91     NIT
# 5       8.55     NIT
# 6       8.66     NIT
# 7       8.92     NIT
# ...

# %%
df.shape
# Out:
# (329, 6)

# %%
df.size
# Out:
# 1974

# %%
df.describe()
# Out:
#               PHONE   Avg. CGPA
# count  3.290000e+02  329.000000
# mean   8.221543e+09    8.672249
# std    1.164712e+09    0.464980
# min    6.201923e+09    6.580000
# 25%    7.278731e+09    8.470000
# 50%    8.337092e+09    8.730000
# 75%    9.123807e+09    9.010000
# max    9.933319e+09    9.460000

# %%
df.dtypes
# Out:
# NAME          object
# EMAIL         object
# PHONE          int64
# STREAM        object
# Avg. CGPA    float64
# COLLEGE       object
# dtype: object

# %%
df.describe(include='all')
# Out:
#               NAME                    EMAIL         PHONE STREAM   Avg. CGPA  \
# count          329                      329  3.290000e+02    329  329.000000
# unique         326                      329           NaN      2         NaN
# top     AMAN KUMAR  1aayushgupta1@gmail.com           NaN    CSE         NaN
# freq             2                        1           NaN    210         NaN
# mean           NaN                      NaN  8.221543e+09    NaN    8.672249
# std            NaN                      NaN  1.164712e+09    NaN    0.464980
# min            NaN                      NaN  6.201923e+09    NaN    6.580000
# 25%            NaN                      NaN  7.278731e+09    NaN    8.470000
# 50%            NaN                      NaN  8.337092e+09    NaN    8.730000
# 75%            NaN                      NaN  9.123807e+09    NaN    9.010000
# max            NaN                      NaN  9.933319e+09    NaN    9.460000
#
#        COLLEGE
# count      329
# ...

# %%
df.NAME
# Out:
# 0             AAYUSH GUPTA
# 1              ABDUL KARIM
# 2                ADIL KHAN
# 3           ADITYA BHUSHAN
# 4                AKASH RAJ
#               ...
# 324             TANAYA PAL
# 325    UDAY SHANKAR SINGHA
# 326            VIBHUTI RAJ
# 327           VINEET YADAV
# 328           YUVRAJ SINGH
# Name: NAME, Length: 329, dtype: object

# %%
df.NAME.describe()
# Out:
# count            329
# unique           326
# top       AMAN KUMAR
# freq               2
# Name: NAME, dtype: object

# %%
df['Avg. CGPA']
# Out:
# 0      7.71
# 1      9.06
# 2      8.91
# 3      8.50
# 4      8.91
#        ...
# 324    8.74
# 325    8.73
# 326    8.82
# 327    8.56
# 328    8.46
# Name: Avg. CGPA, Length: 329, dtype: float64

# %%
max(df['Avg. CGPA'])
# Out:
# 9.46

# %%
df['Avg. CGPA'].describe(include='all')
# Out:
# count    329.000000
# mean       8.672249
# std        0.464980
# min        6.580000
# 25%        8.470000
# 50%        8.730000
# 75%        9.010000
# max        9.460000
# Name: Avg. CGPA, dtype: float64

# %%
df.NAME[0]
# Out:
# 'AAYUSH GUPTA'

# %%
maxcgpa = max(df['Avg. CGPA'])
maxcgpa
# Out:
# 9.46

# %%
df['Avg. CGPA'].idxmax()
# Out:
# 269

# %%
df.loc[df['Avg. CGPA'].idxmax()]
# Out:
# NAME                     KAMYA KUMARI
# EMAIL        kamyakumari140@gmail.com
# PHONE                      8709610318
# STREAM                             IT
# Avg. CGPA                        9.46
# COLLEGE                           NIT
# Name: 269, dtype: object

# %%
df['Avg. CGPA'].idxmin()
# Out:
# 58

# %%
df.loc[df['Avg. CGPA'].idxmin()]
# Out:
# NAME                    GARGI SEN
# EMAIL        gragisen99@gmail.com
# PHONE                  6296631088
# STREAM                        CSE
# Avg. CGPA                    6.58
# COLLEGE                       NIT
# Name: 58, dtype: object

# %%
df.iloc[257]
# Out:
# NAME                    DAIYAN ALAM
# EMAIL        rehanalamkkr@gmail.com
# PHONE                    8102472607
# STREAM                           IT
# Avg. CGPA                      9.19
# COLLEGE                         NIT
# Name: 257, dtype: object

# %%
df.iloc[301]
# Out:
# NAME                    SANA ASIF
# EMAIL        sana98asif@gmail.com
# PHONE                  8229994647
# STREAM                         IT
# Avg. CGPA                    9.26
# COLLEGE                       NIT
# Name: 301, dtype: object

# %%
df.iloc[289]
# Out:
# NAME                          RAJU KUMAR
# EMAIL        er.rajukumar54321@gmail.com
# PHONE                         7079527220
# STREAM                                IT
# Avg. CGPA                           9.29
# COLLEGE                              NIT
# Name: 289, dtype: object

# %%
df
# Out:
#                     NAME                          EMAIL       PHONE STREAM  \
# 0           AAYUSH GUPTA        1aayushgupta1@gmail.com  9831019428    CSE
# 1            ABDUL KARIM             ak.kar8m@gmail.com  9883259930    CSE
# 2              ADIL KHAN      shallycarrera34@gmail.com  8240660823    CSE
# 3         ADITYA BHUSHAN    adityabhushan1517@gmail.com  8002151109    CSE
# 4              AKASH RAJ        akashraj32124@gmail.com  7542046123    CSE
# ..                   ...                            ...         ...    ...
# 324           TANAYA PAL        tanayapalstar@gmail.com  7866937953     IT
# 325  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6377689721     IT
# 326          VIBHUTI RAJ          vibhu421420@gmail.com  7542013535     IT
# 327         VINEET YADAV       yadavvineet872@gmail.com  6391605757     IT
# 328         YUVRAJ SINGH          yuvraj28541@gmail.com  8709187575     IT
#
#      Avg. CGPA COLLEGE
# 0         7.71     NIT
# ...

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#                     NAME                          EMAIL       PHONE STREAM  \
# 1            ABDUL KARIM             ak.kar8m@gmail.com  9883259930    CSE
# 2              ADIL KHAN      shallycarrera34@gmail.com  8240660823    CSE
# 3         ADITYA BHUSHAN    adityabhushan1517@gmail.com  8002151109    CSE
# 4              AKASH RAJ        akashraj32124@gmail.com  7542046123    CSE
# 5             AMAN KUMAR       amanaolsingh55@gmail.com  8340352235    CSE
# ..                   ...                            ...         ...    ...
# 324           TANAYA PAL        tanayapalstar@gmail.com  7866937953     IT
# 325  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6377689721     IT
# 326          VIBHUTI RAJ          vibhu421420@gmail.com  7542013535     IT
# 327         VINEET YADAV       yadavvineet872@gmail.com  6391605757     IT
# 328         YUVRAJ SINGH          yuvraj28541@gmail.com  8709187575     IT
#
#      Avg. CGPA COLLEGE
# 1         9.06     NIT
# ...

# %%
df
# Out:
#                     NAME                          EMAIL       PHONE STREAM  \
# 1            ABDUL KARIM             ak.kar8m@gmail.com  9883259930    CSE
# 2              ADIL KHAN      shallycarrera34@gmail.com  8240660823    CSE
# 3         ADITYA BHUSHAN    adityabhushan1517@gmail.com  8002151109    CSE
# 4              AKASH RAJ        akashraj32124@gmail.com  7542046123    CSE
# 5             AMAN KUMAR       amanaolsingh55@gmail.com  8340352235    CSE
# ..                   ...                            ...         ...    ...
# 324           TANAYA PAL        tanayapalstar@gmail.com  7866937953     IT
# 325  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6377689721     IT
# 326          VIBHUTI RAJ          vibhu421420@gmail.com  7542013535     IT
# 327         VINEET YADAV       yadavvineet872@gmail.com  6391605757     IT
# 328         YUVRAJ SINGH          yuvraj28541@gmail.com  8709187575     IT
#
#      Avg. CGPA COLLEGE
# 1         9.06     NIT
# ...

# %%
df.describe(include='all')
# Out:
#               NAME               EMAIL         PHONE STREAM   Avg. CGPA  \
# count          328                 328  3.280000e+02    328  328.000000
# unique         325                 328           NaN      2         NaN
# top     AMAN KUMAR  ak.kar8m@gmail.com           NaN    CSE         NaN
# freq             2                   1           NaN    209         NaN
# mean           NaN                 NaN  8.216636e+09    NaN    8.675183
# std            NaN                 NaN  1.163081e+09    NaN    0.462631
# min            NaN                 NaN  6.201923e+09    NaN    6.580000
# 25%            NaN                 NaN  7.278654e+09    NaN    8.470000
# 50%            NaN                 NaN  8.317706e+09    NaN    8.730000
# 75%            NaN                 NaN  9.123749e+09    NaN    9.010000
# max            NaN                 NaN  9.933319e+09    NaN    9.460000
#
#        COLLEGE
# count      328
# unique       1
# top        NIT
# freq       328
# mean       NaN
# ...

# %%
import numpy as np
df.iloc[1:3,1]=np.nan

# %%
df.describe(include='all')
# Out:
#               NAME               EMAIL         PHONE STREAM   Avg. CGPA  \
# count          328                 326  3.280000e+02    328  328.000000
# unique         325                 326           NaN      2         NaN
# top     AMAN KUMAR  ak.kar8m@gmail.com           NaN    CSE         NaN
# freq             2                   1           NaN    209         NaN
# mean           NaN                 NaN  8.216636e+09    NaN    8.675183
# std            NaN                 NaN  1.163081e+09    NaN    0.462631
# min            NaN                 NaN  6.201923e+09    NaN    6.580000
# 25%            NaN                 NaN  7.278654e+09    NaN    8.470000
# 50%            NaN                 NaN  8.317706e+09    NaN    8.730000
# 75%            NaN                 NaN  9.123749e+09    NaN    9.010000
# max            NaN                 NaN  9.933319e+09    NaN    9.460000
#
#        COLLEGE
# count      328
# unique       1
# top        NIT
# freq       328
# mean       NaN
# ...

# %%
df
# Out:
#                     NAME                          EMAIL       PHONE STREAM  \
# 1            ABDUL KARIM             ak.kar8m@gmail.com  9883259930    CSE
# 2              ADIL KHAN                            NaN  8240660823    CSE
# 3         ADITYA BHUSHAN                            NaN  8002151109    CSE
# 4              AKASH RAJ        akashraj32124@gmail.com  7542046123    CSE
# 5             AMAN KUMAR       amanaolsingh55@gmail.com  8340352235    CSE
# ..                   ...                            ...         ...    ...
# 324           TANAYA PAL        tanayapalstar@gmail.com  7866937953     IT
# 325  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6377689721     IT
# 326          VIBHUTI RAJ          vibhu421420@gmail.com  7542013535     IT
# 327         VINEET YADAV       yadavvineet872@gmail.com  6391605757     IT
# 328         YUVRAJ SINGH          yuvraj28541@gmail.com  8709187575     IT
#
#      Avg. CGPA COLLEGE
# 1         9.06     NIT
# ...

# %%
df.EMAIL.fillna('missing',inplace=True)

# %%
df
# Out:
#                     NAME                          EMAIL       PHONE STREAM  \
# 1            ABDUL KARIM             ak.kar8m@gmail.com  9883259930    CSE
# 2              ADIL KHAN                        missing  8240660823    CSE
# 3         ADITYA BHUSHAN                        missing  8002151109    CSE
# 4              AKASH RAJ        akashraj32124@gmail.com  7542046123    CSE
# 5             AMAN KUMAR       amanaolsingh55@gmail.com  8340352235    CSE
# ..                   ...                            ...         ...    ...
# 324           TANAYA PAL        tanayapalstar@gmail.com  7866937953     IT
# 325  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6377689721     IT
# 326          VIBHUTI RAJ          vibhu421420@gmail.com  7542013535     IT
# 327         VINEET YADAV       yadavvineet872@gmail.com  6391605757     IT
# 328         YUVRAJ SINGH          yuvraj28541@gmail.com  8709187575     IT
#
#      Avg. CGPA COLLEGE
# 1         9.06     NIT
# ...

# %%
df.iloc[1:3,2:4]=np.nan

# %%
df
# Out:
#                     NAME                          EMAIL         PHONE STREAM  \
# 1            ABDUL KARIM             ak.kar8m@gmail.com  9.883260e+09    CSE
# 2              ADIL KHAN                        missing           NaN    NaN
# 3         ADITYA BHUSHAN                        missing           NaN    NaN
# 4              AKASH RAJ        akashraj32124@gmail.com  7.542046e+09    CSE
# 5             AMAN KUMAR       amanaolsingh55@gmail.com  8.340352e+09    CSE
# ..                   ...                            ...           ...    ...
# 324           TANAYA PAL        tanayapalstar@gmail.com  7.866938e+09     IT
# 325  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6.377690e+09     IT
# 326          VIBHUTI RAJ          vibhu421420@gmail.com  7.542014e+09     IT
# 327         VINEET YADAV       yadavvineet872@gmail.com  6.391606e+09     IT
# 328         YUVRAJ SINGH          yuvraj28541@gmail.com  8.709188e+09     IT
#
#      Avg. CGPA COLLEGE
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                     NAME                          EMAIL         PHONE STREAM  \
# 1            ABDUL KARIM             ak.kar8m@gmail.com  9.883260e+09    CSE
# 4              AKASH RAJ        akashraj32124@gmail.com  7.542046e+09    CSE
# 5             AMAN KUMAR       amanaolsingh55@gmail.com  8.340352e+09    CSE
# 6             AMAN KUMAR         aman.cute329@gmail.com  6.287959e+09    CSE
# 7       AMAN KUMAR SINHA           amankr7100@gmail.com  8.092678e+09    CSE
# ..                   ...                            ...           ...    ...
# 324           TANAYA PAL        tanayapalstar@gmail.com  7.866938e+09     IT
# 325  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6.377690e+09     IT
# 326          VIBHUTI RAJ          vibhu421420@gmail.com  7.542014e+09     IT
# 327         VINEET YADAV       yadavvineet872@gmail.com  6.391606e+09     IT
# 328         YUVRAJ SINGH          yuvraj28541@gmail.com  8.709188e+09     IT
#
#      Avg. CGPA COLLEGE
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                     NAME                          EMAIL         PHONE STREAM  \
# 0            ABDUL KARIM             ak.kar8m@gmail.com  9.883260e+09    CSE
# 1              AKASH RAJ        akashraj32124@gmail.com  7.542046e+09    CSE
# 2             AMAN KUMAR       amanaolsingh55@gmail.com  8.340352e+09    CSE
# 3             AMAN KUMAR         aman.cute329@gmail.com  6.287959e+09    CSE
# 4       AMAN KUMAR SINHA           amankr7100@gmail.com  8.092678e+09    CSE
# ..                   ...                            ...           ...    ...
# 321           TANAYA PAL        tanayapalstar@gmail.com  7.866938e+09     IT
# 322  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6.377690e+09     IT
# 323          VIBHUTI RAJ          vibhu421420@gmail.com  7.542014e+09     IT
# 324         VINEET YADAV       yadavvineet872@gmail.com  6.391606e+09     IT
# 325         YUVRAJ SINGH          yuvraj28541@gmail.com  8.709188e+09     IT
#
#      Avg. CGPA COLLEGE
# ...

# %%
df['University']='JIS'

# %%
df
# Out:
#                     NAME                          EMAIL         PHONE STREAM  \
# 0            ABDUL KARIM             ak.kar8m@gmail.com  9.883260e+09    CSE
# 1              AKASH RAJ        akashraj32124@gmail.com  7.542046e+09    CSE
# 2             AMAN KUMAR       amanaolsingh55@gmail.com  8.340352e+09    CSE
# 3             AMAN KUMAR         aman.cute329@gmail.com  6.287959e+09    CSE
# 4       AMAN KUMAR SINHA           amankr7100@gmail.com  8.092678e+09    CSE
# ..                   ...                            ...           ...    ...
# 321           TANAYA PAL        tanayapalstar@gmail.com  7.866938e+09     IT
# 322  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com  6.377690e+09     IT
# 323          VIBHUTI RAJ          vibhu421420@gmail.com  7.542014e+09     IT
# 324         VINEET YADAV       yadavvineet872@gmail.com  6.391606e+09     IT
# 325         YUVRAJ SINGH          yuvraj28541@gmail.com  8.709188e+09     IT
#
#      Avg. CGPA COLLEGE University
# ...

# %%
df.drop('PHONE',axis=1,inplace=True)    # delete PHNOE Column

# %%
df
# Out:
#                     NAME                          EMAIL STREAM  Avg. CGPA  \
# 0            ABDUL KARIM             ak.kar8m@gmail.com    CSE       9.06
# 1              AKASH RAJ        akashraj32124@gmail.com    CSE       8.91
# 2             AMAN KUMAR       amanaolsingh55@gmail.com    CSE       8.55
# 3             AMAN KUMAR         aman.cute329@gmail.com    CSE       8.66
# 4       AMAN KUMAR SINHA           amankr7100@gmail.com    CSE       8.92
# ..                   ...                            ...    ...        ...
# 321           TANAYA PAL        tanayapalstar@gmail.com     IT       8.74
# 322  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com     IT       8.73
# 323          VIBHUTI RAJ          vibhu421420@gmail.com     IT       8.82
# 324         VINEET YADAV       yadavvineet872@gmail.com     IT       8.56
# 325         YUVRAJ SINGH          yuvraj28541@gmail.com     IT       8.46
#
#     COLLEGE University
# 0       NIT        JIS
# 1       NIT        JIS
# ...

# %%
styler = df.style

# %%
styler.set_table_styles([{'selector': 'th', 'props': [('background-color', 'red')]}])
# Out:
# <style type="text/css">
# #T_4ce6d_ th {
#   background-color: red;
# }
# </style>
# <table id="T_4ce6d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >NAME</th>
#       <th class="col_heading level0 col1" >EMAIL</th>
#       <th class="col_heading level0 col2" >STREAM</th>
#       <th class="col_heading level0 col3" >Avg. CGPA</th>
#       <th class="col_heading level0 col4" >COLLEGE</th>
#       <th class="col_heading level0 col5" >University</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ce6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ce6d_row0_col0" class="data row0 col0" >ABDUL KARIM</td>
#       <td id="T_4ce6d_row0_col1" class="data row0 col1" >ak.kar8m@gmail.com</td>
#       <td id="T_4ce6d_row0_col2" class="data row0 col2" >CSE</td>
#       <td id="T_4ce6d_row0_col3" class="data row0 col3" >9.060000</td>
# ...

# %%
styler.set_table_styles([{'selector': 'th', 'props': [('color', 'black')]}])
# Out:
# <style type="text/css">
# #T_4ce6d_ th {
#   color: black;
# }
# </style>
# <table id="T_4ce6d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >NAME</th>
#       <th class="col_heading level0 col1" >EMAIL</th>
#       <th class="col_heading level0 col2" >STREAM</th>
#       <th class="col_heading level0 col3" >Avg. CGPA</th>
#       <th class="col_heading level0 col4" >COLLEGE</th>
#       <th class="col_heading level0 col5" >University</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ce6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ce6d_row0_col0" class="data row0 col0" >ABDUL KARIM</td>
#       <td id="T_4ce6d_row0_col1" class="data row0 col1" >ak.kar8m@gmail.com</td>
#       <td id="T_4ce6d_row0_col2" class="data row0 col2" >CSE</td>
#       <td id="T_4ce6d_row0_col3" class="data row0 col3" >9.060000</td>
# ...

# %%
styler.set_table_styles([{'selector': 'th', 'props': [('font-weight', 'bold')]}])
# Out:
# <style type="text/css">
# #T_4ce6d_ th {
#   font-weight: bold;
# }
# </style>
# <table id="T_4ce6d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >NAME</th>
#       <th class="col_heading level0 col1" >EMAIL</th>
#       <th class="col_heading level0 col2" >STREAM</th>
#       <th class="col_heading level0 col3" >Avg. CGPA</th>
#       <th class="col_heading level0 col4" >COLLEGE</th>
#       <th class="col_heading level0 col5" >University</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ce6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ce6d_row0_col0" class="data row0 col0" >ABDUL KARIM</td>
#       <td id="T_4ce6d_row0_col1" class="data row0 col1" >ak.kar8m@gmail.com</td>
#       <td id="T_4ce6d_row0_col2" class="data row0 col2" >CSE</td>
#       <td id="T_4ce6d_row0_col3" class="data row0 col3" >9.060000</td>
# ...

# %%
styler.set_table_styles([{'selector': 'th', 'props': [('font-size', '15px')]}])
# Out:
# <style type="text/css">
# #T_4ce6d_ th {
#   font-size: 15px;
# }
# </style>
# <table id="T_4ce6d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >NAME</th>
#       <th class="col_heading level0 col1" >EMAIL</th>
#       <th class="col_heading level0 col2" >STREAM</th>
#       <th class="col_heading level0 col3" >Avg. CGPA</th>
#       <th class="col_heading level0 col4" >COLLEGE</th>
#       <th class="col_heading level0 col5" >University</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ce6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ce6d_row0_col0" class="data row0 col0" >ABDUL KARIM</td>
#       <td id="T_4ce6d_row0_col1" class="data row0 col1" >ak.kar8m@gmail.com</td>
#       <td id="T_4ce6d_row0_col2" class="data row0 col2" >CSE</td>
#       <td id="T_4ce6d_row0_col3" class="data row0 col3" >9.060000</td>
# ...

# %%
styler.set_table_styles([{'selector': 'td', 'props': [('font-size', '13px')]}])
# Out:
# <style type="text/css">
# #T_4ce6d_ td {
#   font-size: 13px;
# }
# </style>
# <table id="T_4ce6d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >NAME</th>
#       <th class="col_heading level0 col1" >EMAIL</th>
#       <th class="col_heading level0 col2" >STREAM</th>
#       <th class="col_heading level0 col3" >Avg. CGPA</th>
#       <th class="col_heading level0 col4" >COLLEGE</th>
#       <th class="col_heading level0 col5" >University</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ce6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ce6d_row0_col0" class="data row0 col0" >ABDUL KARIM</td>
#       <td id="T_4ce6d_row0_col1" class="data row0 col1" >ak.kar8m@gmail.com</td>
#       <td id="T_4ce6d_row0_col2" class="data row0 col2" >CSE</td>
#       <td id="T_4ce6d_row0_col3" class="data row0 col3" >9.060000</td>
# ...

# %%
styler.set_table_styles([{'selector': 'td', 'props': [('background-color', 'pink')]}])
# Out:
# <style type="text/css">
# #T_4ce6d_ td {
#   background-color: pink;
# }
# </style>
# <table id="T_4ce6d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >NAME</th>
#       <th class="col_heading level0 col1" >EMAIL</th>
#       <th class="col_heading level0 col2" >STREAM</th>
#       <th class="col_heading level0 col3" >Avg. CGPA</th>
#       <th class="col_heading level0 col4" >COLLEGE</th>
#       <th class="col_heading level0 col5" >University</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ce6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ce6d_row0_col0" class="data row0 col0" >ABDUL KARIM</td>
#       <td id="T_4ce6d_row0_col1" class="data row0 col1" >ak.kar8m@gmail.com</td>
#       <td id="T_4ce6d_row0_col2" class="data row0 col2" >CSE</td>
#       <td id="T_4ce6d_row0_col3" class="data row0 col3" >9.060000</td>
# ...

# %%
df.to_csv('NITIAN.csv')

# %%
df
# Out:
#                     NAME                          EMAIL STREAM  Avg. CGPA  \
# 0            ABDUL KARIM             ak.kar8m@gmail.com    CSE       9.06
# 1              AKASH RAJ        akashraj32124@gmail.com    CSE       8.91
# 2             AMAN KUMAR       amanaolsingh55@gmail.com    CSE       8.55
# 3             AMAN KUMAR         aman.cute329@gmail.com    CSE       8.66
# 4       AMAN KUMAR SINHA           amankr7100@gmail.com    CSE       8.92
# ..                   ...                            ...    ...        ...
# 321           TANAYA PAL        tanayapalstar@gmail.com     IT       8.74
# 322  UDAY SHANKAR SINGHA  udayshankarsingha99@gmail.com     IT       8.73
# 323          VIBHUTI RAJ          vibhu421420@gmail.com     IT       8.82
# 324         VINEET YADAV       yadavvineet872@gmail.com     IT       8.56
# 325         YUVRAJ SINGH          yuvraj28541@gmail.com     IT       8.46
#
#     COLLEGE University
# 0       NIT        JIS
# 1       NIT        JIS
# ...
